# %%
from __future__ import print_function
# %matplotlib inline
# %pylab inline
# %load_ext memory_profiler
import matplotlib.pyplot as plt
import seaborn; seaborn.set_style('whitegrid')
import numpy
import itertools
from tabulate import tabulate
from pomegranate import *
from pomegranate import BayesianNetwork
import iac_org as iacO

import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/pramitmallick/anaconda/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['dist']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# !python iacO.py
attributes = ["gang", "age", "edu", "mar", "occ", "name"]

s = np.random.normal(0, 0.005, 1)
print(s[0],abs)
# Out:
# -0.00373914147639046

# %%
def prob(evidences, atts):
    count, total = 0, 0
    for datapoint in iacO.data:
        inc = True
        for key in evidences:
            inc = inc and datapoint[key] == evidences[key]
        if inc:
            total += 1
            f = True
            for key in atts:
                f = f and datapoint[key] == atts[key]
            if f:
                count += 1
    return count, total, float(count)/total

def enums(key):
    vals = set()
    for datapoint in iacO.data:
        if datapoint[key] not in vals:
            vals.add(datapoint[key])
    return list(vals)

# %%
print(prob({'gang': 'Jets', 'occ': 'pusher'},{'mar': 'single'}))
print(prob({},{'gang': 'Jets'}))
print(prob({},{'name': 'John'}))
print(prob({'name': 'John'},{'gang': 'Jets'}), prob({'name': 'John'},{'gang': 'Sharks'}))
print(len(iacO.data))
print(enums("name"), enums("edu"))
# Out:
# (4, 5, 0.8)
# (15, 27, 0.5555555555555556)
# (1, 27, 0.037037037037037035)
# (1, 1, 1.0) (0, 1, 0.0)
# 27
# ['Pete', 'Ned', 'Jim', 'Ralph', 'Nick', 'Clyde', 'Rick', 'John', 'Lance', 'Ken', 'Mike', 'Fred', 'Dave', 'Ike', 'Earl', 'Ol', 'Don', 'Phil', 'Neal', 'Greg', 'Gene', 'Art', 'Sam', 'Al', 'Doug', 'George', 'Karl'] ['HS', 'JH', 'COL']

# %%
import collections
noisy_p_feature_given_hidden = {}
c = 0
for name in enums(attributes[-1]):
#     p1 = True if name == "George" else False
    noisy_p_feature_given_hidden[name] = {}
    for att in attributes[:-1]:
#         p2 = True if att == "edu" else False
        pl = 0.1/(len(enums(att))-1)
        for val in enums(att):
            noisy_p_feature_given_hidden[name][val] = 0.9 if prob({"name":name},{att:val})[2] == 1.0 else pl
            c += 1 if prob({"name":name},{att:val})[2] == 1 else 0
#             if p1 and p2:
#                 print(prob({"name":name},{att:val})[2], pl, name, att, val)
#                 print(prob({"name":name},{att:val})[2] == 1)
            
print(prob({"name":"George"},{"edu":"JH"})[2], prob({"name":"George"},{"edu":"COL"})[2], prob({"name":"George"},{"edu":"HS"})[2])
print(c/27, noisy_p_feature_given_hidden["George"]["JH"], noisy_p_feature_given_hidden["George"]["COL"], noisy_p_feature_given_hidden["George"]["HS"])
# Out:
# 1.0 0.0 0.0
# 5 0.9 0.05 0.05

# %%
enums("edu")
# Out:
# ['HS', 'JH', 'COL']

# %%
# attributes = ["gang", "age", "edu", "mar", "occ"]
attributes = ["gang", "age", "edu", "mar", "occ", "name"]
distributions = {}
for att in attributes:
    probs = {}
    vals = enums(att)
    for val in vals:
        probs[val] = prob({},{att:val})[2]
    distributions[att] = DiscreteDistribution(probs)

dataInArray = []
n = {}
for datapoint in iacO.data:
    row = []
    for att in attributes:
        row.append(datapoint[att])
#     row.append(datapoint["name"])
    dataInArray.append(row)
#     n[tuple(row)] = datapoint["name"]
print(len(dataInArray))
# print(tabulate(dataInArray))
# Out:
# 27

# %%
modelFromData = BayesianNetwork.from_samples(dataInArray, algorithm='exact')
print(modelFromData.structure)
modelFromData.plot()
# Out:
# ((2,), (0,), (), (), (), ())

# %%
src = []
dist = []
states = []
for att in attributes:
    src.append(enums(att))
    dist.append(distributions[att])
CPT = []
cpt_dict = {}
c = 0
for element in itertools.product(*src):
    temp = list(element)
    if temp in dataInArray:
        CPT.append(temp+[1])
        c += 1
        cpt_dict[element] = 1
    else:
        CPT.append(temp+[0])
        cpt_dict[element] = 0
# CPT
# print(cpt_dict)
# print(tabulate(CPT, headers=attributes+["prob"]))

# %%
# p(h|e) = p(h)p(envidence|hyp)/sum(p(h)p(envidence|hyp))
# noisy_p_feature_given_hidden["George"]["JH"]
Noisy_CPT = []
d_evidence = {}
for element in itertools.product(*src):
    name = element[-1]
    evidences = element[:-1]
#     print(evidences, name)
    if evidences not in d_evidence:
        d_evidence[evidences] = {}
    if name not in d_evidence[evidences]:
        d_evidence[evidences][name] = 1
    for evi in evidences:
#         print(evi)
        d_evidence[evidences][name] *= noisy_p_feature_given_hidden[name][evi]
    
eq_evidence = {}
for element in itertools.product(*src[:-1]):
#     print(element)
    evidences = element
    eq_evidence[evidences] = 0
    for name in enums("name"):
        eq_evidence[evidences] += d_evidence[evidences][name]

        
# evis = ('Jets', '20s', 'HS', 'married', 'pusher')
# print(d_evidence[evis])

c = 0
for element in itertools.product(*src):
    name = element[-1]
    evidences = element[:-1]
    temp = list(element)
    normalized_noisy_prob = d_evidence[evidences][name]/eq_evidence[evidences]
#     Noisy_CPT.append(temp+[normalized_noisy_prob])
    if temp in dataInArray:
        Noisy_CPT.append(temp+[normalized_noisy_prob]+[1])
        c += 1
    else:
        Noisy_CPT.append(temp+[normalized_noisy_prob]+[0])

# %%
# print(tabulate(CPT, headers=attributes+["prob"]))
print(tabulate(Noisy_CPT, headers=attributes+["noisy prob", "actual"]))
# Out:
# gang    age    edu    mar       occ      name      noisy prob    actual
# ------  -----  -----  --------  -------  ------  ------------  --------
# Jets    20s    HS     single    bookie   Pete     0.837869            1
# Jets    20s    HS     single    bookie   Ned      1.59631e-05         0
# Jets    20s    HS     single    bookie   Jim      0.000143667         0
# Jets    20s    HS     single    bookie   Ralph    0.000143667         0
# Jets    20s    HS     single    bookie   Nick     0.000287335         0
# Jets    20s    HS     single    bookie   Clyde    0.00258601          0
# Jets    20s    HS     single    bookie   Rick     1.59631e-05         0
# Jets    20s    HS     single    bookie   John     0.000143667         0
# Jets    20s    HS     single    bookie   Lance    0.000143667         0
# Jets    20s    HS     single    bookie   Ken      0.00517203          0
# Jets    20s    HS     single    bookie   Mike     0.00258601          0
# Jets    20s    HS     single    bookie   Fred     0.0465483           0
# Jets    20s    HS     single    bookie   Dave     1.59631e-05         0
# Jets    20s    HS     single    bookie   Ike      0.000287335         0
# Jets    20s    HS     single    bookie   Earl     1.59631e-05         0
# Jets    20s    HS     single    bookie   Ol       8.86836e-07         0
# Jets    20s    HS     single    bookie   Don      8.86836e-07         0
# Jets    20s    HS     single    bookie   Phil     8.86836e-07         0
# Jets    20s    HS     single    bookie   Neal     0.00517203          0
# Jets    20s    HS     single    bookie   Greg     0.00258601          0
# Jets    20s    HS     single    bookie   Gene     0.00258601          0
# Jets    20s    HS     single    bookie   Art      0.000143667         0
# Jets    20s    HS     single    bookie   Sam      0.0465483           0
# Jets    20s    HS     single    bookie   Al       7.98153e-06         0
# Jets    20s    HS     single    bookie   Doug     0.0465483           0
# Jets    20s    HS     single    bookie   George   0.000143667         0
# Jets    20s    HS     single    bookie   Karl     0.000287335         0
# Jets    20s    HS     single    burglar  Pete     0.222916            0
# Jets    20s    HS     single    burglar  Ned      4.24699e-06         0
# Jets    20s    HS     single    burglar  Jim      0.0123842           0
# Jets    20s    HS     single    burglar  Ralph    0.000688012         0
# Jets    20s    HS     single    burglar  Nick     0.00137602          0
# Jets    20s    HS     single    burglar  Clyde    0.000688012         0
# Jets    20s    HS     single    burglar  Rick     0.00137602          0
# Jets    20s    HS     single    burglar  John     0.0123842           0
# Jets    20s    HS     single    burglar  Lance    0.0123842           0
# Jets    20s    HS     single    burglar  Ken      0.445832            0
# Jets    20s    HS     single    burglar  Mike     0.000688012         0
# Jets    20s    HS     single    burglar  Fred     0.222916            0
# Jets    20s    HS     single    burglar  Dave     7.64458e-05         0
# Jets    20s    HS     single    burglar  Ike      7.64458e-05         0
# Jets    20s    HS     single    burglar  Earl     0.00137602          0
# Jets    20s    HS     single    burglar  Ol       4.24699e-06         0
# Jets    20s    HS     single    burglar  Don      7.64458e-05         0
# Jets    20s    HS     single    burglar  Phil     4.24699e-06         0
# Jets    20s    HS     single    burglar  Neal     0.00137602          0
# Jets    20s    HS     single    burglar  Greg     0.0123842           0
# Jets    20s    HS     single    burglar  Gene     0.0123842           0
# Jets    20s    HS     single    burglar  Art      0.000688012         0
# Jets    20s    HS     single    burglar  Sam      0.0123842           0
# Jets    20s    HS     single    burglar  Al       0.000688012         0
# Jets    20s    HS     single    burglar  Doug     0.0123842           0
# Jets    20s    HS     single    burglar  George   0.0123842           0
# Jets    20s    HS     single    burglar  Karl     7.64458e-05         0
# Jets    20s    HS     single    pusher   Pete     0.0465602           0
# Jets    20s    HS     single    pusher   Ned      8.87064e-07         0
# Jets    20s    HS     single    pusher   Jim      0.000143704         0
# Jets    20s    HS     single    pusher   Ralph    0.00258668          0
# Jets    20s    HS     single    pusher   Nick     0.00517335          0
# Jets    20s    HS     single    pusher   Clyde    0.000143704         0
# Jets    20s    HS     single    pusher   Rick     1.59671e-05         0
# Jets    20s    HS     single    pusher   John     0.000143704         0
# Jets    20s    HS     single    pusher   Lance    0.000143704         0
# Jets    20s    HS     single    pusher   Ken      0.00517335          0
# Jets    20s    HS     single    pusher   Mike     0.000143704         0
# Jets    20s    HS     single    pusher   Fred     0.838083            1
# Jets    20s    HS     single    pusher   Dave     0.000287409         0
# Jets    20s    HS     single    pusher   Ike      1.59671e-05         0
# Jets    20s    HS     single    pusher   Earl     1.59671e-05         0
# Jets    20s    HS     single    pusher   Ol       1.59671e-05         0
# Jets    20s    HS     single    pusher   Don      8.87064e-07         0
# Jets    20s    HS     single    pusher   Phil     1.59671e-05         0
# Jets    20s    HS     single    pusher   Neal     0.000287409         0
# Jets    20s    HS     single    pusher   Greg     0.0465602           0
# Jets    20s    HS     single    pusher   Gene     0.0465602           0
# Jets    20s    HS     single    pusher   Art      0.00258668          0
# Jets    20s    HS     single    pusher   Sam      0.00258668          0
# Jets    20s    HS     single    pusher   Al       7.98357e-06         0
# Jets    20s    HS     single    pusher   Doug     0.00258668          0
# Jets    20s    HS     single    pusher   George   0.000143704         0
# Jets    20s    HS     single    pusher   Karl     1.59671e-05         0
# Jets    20s    HS     married   bookie   Pete     0.410704            0
# Jets    20s    HS     married   bookie   Ned      0.00253521          0
# Jets    20s    HS     married   bookie   Jim      0.00126761          0
# Jets    20s    HS     married   bookie   Ralph    7.04225e-05         0
# Jets    20s    HS     married   bookie   Nick     0.000140845         0
# Jets    20s    HS     married   bookie   Clyde    0.00126761          0
# Jets    20s    HS     married   bookie   Rick     0.000140845         0
# Jets    20s    HS     married   bookie   John     0.0228169           0
# Jets    20s    HS     married   bookie   Lance    0.0228169           0
# Jets    20s    HS     married   bookie   Ken      0.00253521          0
# Jets    20s    HS     married   bookie   Mike     0.00126761          0
# Jets    20s    HS     married   bookie   Fred     0.0228169           0
# Jets    20s    HS     married   bookie   Dave     0.000140845         0
# Jets    20s    HS     married   bookie   Ike      0.000140845         0
# Jets    20s    HS     married   bookie   Earl     0.00253521          0
# Jets    20s    HS     married   bookie   Ol       0.000140845         0
# Jets    20s    HS     married   bookie   Don      0.000140845         0
# Jets    20s    HS     married   bookie   Phil     0.000140845         0
# Jets    20s    HS     married   bookie   Neal     0.00253521          0
# Jets    20s    HS     married   bookie   Greg     0.410704            0
# Jets    20s    HS     married   bookie   Gene     0.00126761          0
# Jets    20s    HS     married   bookie   Art      7.04225e-05         0
# Jets    20s    HS     married   bookie   Sam      0.0228169           0
# Jets    20s    HS     married   bookie   Al       0.00126761          0
# Jets    20s    HS     married   bookie   Doug     0.0228169           0
# Jets    20s    HS     married   bookie   George   0.00126761          0
# Jets    20s    HS     married   bookie   Karl     0.0456338           0
# Jets    20s    HS     married   burglar  Pete     0.0157357           0
# Jets    20s    HS     married   burglar  Ned      9.7134e-05          0
# Jets    20s    HS     married   burglar  Jim      0.0157357           0
# Jets    20s    HS     married   burglar  Ralph    4.8567e-05          0
# Jets    20s    HS     married   burglar  Nick     9.7134e-05          0
# Jets    20s    HS     married   burglar  Clyde    4.8567e-05          0
# Jets    20s    HS     married   burglar  Rick     0.00174841          0
# Jets    20s    HS     married   burglar  John     0.283243            0
# Jets    20s    HS     married   burglar  Lance    0.283243            0
# Jets    20s    HS     married   burglar  Ken      0.0314714           0
# Jets    20s    HS     married   burglar  Mike     4.8567e-05          0
# Jets    20s    HS     married   burglar  Fred     0.0157357           0
# Jets    20s    HS     married   burglar  Dave     9.7134e-05          0
# Jets    20s    HS     married   burglar  Ike      5.39633e-06         0
# Jets    20s    HS     married   burglar  Earl     0.0314714           0
# Jets    20s    HS     married   burglar  Ol       9.7134e-05          0
# Jets    20s    HS     married   burglar  Don      0.00174841          0
# Jets    20s    HS     married   burglar  Phil     9.7134e-05          0
# Jets    20s    HS     married   burglar  Neal     9.7134e-05          0
# Jets    20s    HS     married   burglar  Greg     0.283243            0
# Jets    20s    HS     married   burglar  Gene     0.000874206         0
# Jets    20s    HS     married   burglar  Art      4.8567e-05          0
# Jets    20s    HS     married   burglar  Sam      0.000874206         0
# Jets    20s    HS     married   burglar  Al       0.0157357           0
# Jets    20s    HS     married   burglar  Doug     0.000874206         0
# Jets    20s    HS     married   burglar  George   0.0157357           0
# Jets    20s    HS     married   burglar  Karl     0.00174841          0
# Jets    20s    HS     married   pusher   Pete     0.0028802           0
# Jets    20s    HS     married   pusher   Ned      1.7779e-05          0
# Jets    20s    HS     married   pusher   Jim      0.000160011         0
# Jets    20s    HS     married   pusher   Ralph    0.000160011         0
# Jets    20s    HS     married   pusher   Nick     0.000320022         0
# Jets    20s    HS     married   pusher   Clyde    8.88951e-06         0
# Jets    20s    HS     married   pusher   Rick     1.7779e-05          0
# Jets    20s    HS     married   pusher   John     0.0028802           0
# Jets    20s    HS     married   pusher   Lance    0.0028802           0
# Jets    20s    HS     married   pusher   Ken      0.000320022         0
# Jets    20s    HS     married   pusher   Mike     8.88951e-06         0
# Jets    20s    HS     married   pusher   Fred     0.0518436           0
# Jets    20s    HS     married   pusher   Dave     0.000320022         0
# Jets    20s    HS     married   pusher   Ike      9.87724e-07         0
# Jets    20s    HS     married   pusher   Earl     0.000320022         0
# Jets    20s    HS     married   pusher   Ol       0.000320022         0
# Jets    20s    HS     married   pusher   Don      1.7779e-05          0
# Jets    20s    HS     married   pusher   Phil     0.000320022         0
# Jets    20s    HS     married   pusher   Neal     1.7779e-05          0
# Jets    20s    HS     married   pusher   Greg     0.933185            1
# Jets    20s    HS     married   pusher   Gene     0.0028802           0
# Jets    20s    HS     married   pusher   Art      0.000160011         0
# Jets    20s    HS     married   pusher   Sam      0.000160011         0
# Jets    20s    HS     married   pusher   Al       0.000160011         0
# Jets    20s    HS     married   pusher   Doug     0.000160011         0
# Jets    20s    HS     married   pusher   George   0.000160011         0
# Jets    20s    HS     married   pusher   Karl     0.000320022         0
# Jets    20s    HS     divorced  bookie   Pete     0.723813            0
# Jets    20s    HS     divorced  bookie   Ned      0.000248221         0
# Jets    20s    HS     divorced  bookie   Jim      0.0402118           0
# Jets    20s    HS     divorced  bookie   Ralph    0.000124111         0
# Jets    20s    HS     divorced  bookie   Nick     0.000248221         0
# Jets    20s    HS     divorced  pusher   Pete     0.0234149           0
# Jets    20s    HS     divorced  pusher   Ned      8.02981e-06         0
# Jets    20s    HS     divorced  pusher   Jim      0.0234149           0
# Jets    20s    HS     divorced  pusher   Ralph    0.00130083          0
# Jets    20s    HS     divorced  pusher   Nick     0.00260166          0
# Jets    20s    HS     divorced  pusher   Clyde    7.22683e-05         0
# Jets    20s    HS     divorced  pusher   Rick     0.00260166          0
# Jets    20s    HS     divorced  pusher   John     0.00130083          0
# Jets    20s    HS     divorced  pusher   Lance    0.00130083          0
# Jets    20s    HS     divorced  pusher   Ken      0.00260166          0
# Jets    20s    HS     divorced  pusher   Mike     7.22683e-05         0
# Jets    20s    HS     divorced  pusher   Fred     0.421468            0
# Jets    20s    HS     divorced  pusher   Dave     0.0468298           0
# Jets    20s    HS     divorced  pusher   Ike      8.02981e-06         0
# Jets    20s    HS     divorced  pusher   Earl     0.000144537         0
# Jets    20s    HS     divorced  pusher   Ol       0.000144537         0
# Jets    20s    HS     divorced  pusher   Don      8.02981e-06         0
# Jets    20s    HS     divorced  pusher   Phil     0.000144537         0
# Jets    20s    HS     divorced  pusher   Neal     0.000144537         0
# Jets    20s    HS     divorced  pusher   Greg     0.421468            0
# Jets    20s    HS     divorced  pusher   Gene     0.0234149           0
# Jets    20s    HS     divorced  pusher   Art      0.00130083          0
# Jets    20s    HS     divorced  pusher   Sam      0.00130083          0
# Jets    20s    HS     divorced  pusher   Al       7.22683e-05         0
# Jets    20s    HS     divorced  pusher   Doug     0.00130083          0
# Jets    20s    HS     divorced  pusher   George   0.0234149           0
# Jets    20s    HS     divorced  pusher   Karl     0.000144537         0
# Jets    20s    JH     single    bookie   Pete     0.215947            0
# Jets    20s    JH     single    bookie   Ned      7.40558e-05         0
# Jets    20s    JH     single    bookie   Jim      0.011997            0
# Jets    20s    JH     single    bookie   Ralph    0.011997            0
# Jets    20s    JH     single    bookie   Nick     7.40558e-05         0
# Jets    20s    JH     single    bookie   Clyde    0.215947            0
# Jets    20s    JH     single    bookie   Rick     4.11421e-06         0
# Jets    20s    JH     single    bookie   John     0.011997            0
# Jets    20s    JH     single    bookie   Lance    0.011997            0
# Jets    20s    JH     single    bookie   Ken      0.001333            0
# Jets    20s    JH     single    bookie   Mike     0.215947            0
# Jets    20s    JH     single    bookie   Fred     0.011997            0
# Jets    20s    JH     single    bookie   Dave     4.11421e-06         0
# Jets    20s    JH     single    bookie   Ike      0.0239941           0
# Jets    20s    JH     single    bookie   Earl     4.11421e-06         0
# Jets    20s    JH     single    bookie   Ol       4.11421e-06         0
# Jets    20s    JH     single    bookie   Don      4.11421e-06         0
# Jets    20s    JH     single    bookie   Phil     4.11421e-06         0
# Jets    20s    JH     single    bookie   Neal     0.001333            0
# Jets    20s    JH     single    bookie   Greg     0.000666502         0
# Jets    20s    JH     single    bookie   Gene     0.011997            0
# Jets    20s    JH     single    bookie   Art      0.011997            0
# Jets    20s    JH     single    bookie   Sam      0.215947            0
# Jets    20s    JH     single    bookie   Al       0.000666502         0
# Jets    20s    JH     single    bookie   Doug     0.011997            0
# Jets    20s    JH     single    bookie   George   0.011997            0
# Jets    20s    JH     single    bookie   Karl     7.40558e-05         0
# Jets    20s    JH     single    burglar  Pete     0.0120113           0
# Jets    20s    JH     single    burglar  Ned      4.11911e-06         0
# Jets    20s    JH     single    burglar  Jim      0.216204            0
# Jets    20s    JH     single    burglar  Ralph    0.0120113           0
# Jets    20s    JH     single    burglar  Nick     7.41439e-05         0
# Jets    20s    JH     single    burglar  Clyde    0.0120113           0
# Jets    20s    JH     single    burglar  Rick     7.41439e-05         0
# Jets    20s    JH     single    burglar  John     0.216204            0
# Jets    20s    JH     single    burglar  Lance    0.216204            0
# Jets    20s    JH     single    burglar  Ken      0.0240226           0
# Jets    20s    JH     single    burglar  Mike     0.0120113           0
# Jets    20s    JH     single    burglar  Fred     0.0120113           0
# Jets    20s    JH     single    burglar  Dave     4.11911e-06         0
# Jets    20s    JH     single    burglar  Ike      0.00133459          0
# Jets    20s    JH     single    burglar  Earl     7.41439e-05         0
# Jets    20s    JH     single    burglar  Ol       4.11911e-06         0
# Jets    20s    JH     single    burglar  Don      7.41439e-05         0
# Jets    20s    JH     single    burglar  Phil     4.11911e-06         0
# Jets    20s    JH     single    burglar  Neal     7.41439e-05         0
# Jets    20s    JH     single    burglar  Greg     0.000667296         0
# Jets    20s    JH     single    burglar  Gene     0.0120113           0
# Jets    20s    JH     single    burglar  Art      0.0120113           0
# Jets    20s    JH     single    burglar  Sam      0.0120113           0
# Jets    20s    JH     single    burglar  Al       0.0120113           0
# Jets    20s    JH     single    burglar  Doug     0.000667296         0
# Jets    20s    JH     single    burglar  George   0.216204            0
# Jets    20s    JH     single    burglar  Karl     4.11911e-06         0
# Jets    20s    JH     single    pusher   Pete     0.0122743           0
# Jets    20s    JH     single    pusher   Ned      4.2093e-06          0
# Jets    20s    JH     single    pusher   Jim      0.0122743           0
# Jets    20s    JH     single    pusher   Ralph    0.220938            0
# Jets    20s    JH     single    pusher   Nick     0.00136381          0
# Jets    20s    JH     single    pusher   Clyde    0.0122743           0
# Jets    20s    JH     single    pusher   Rick     4.2093e-06          0
# Jets    20s    JH     single    pusher   John     0.0122743           0
# Jets    20s    JH     single    pusher   Lance    0.0122743           0
# Jets    20s    JH     single    pusher   Ken      0.00136381          0
# Jets    20s    JH     single    pusher   Mike     0.0122743           0
# Jets    20s    JH     single    pusher   Fred     0.220938            0
# Jets    20s    JH     single    pusher   Dave     7.57675e-05         0
# Jets    20s    JH     single    pusher   Ike      0.00136381          0
# Jets    20s    JH     single    pusher   Earl     4.2093e-06          0
# Jets    20s    JH     single    pusher   Ol       7.57675e-05         0
# Jets    20s    JH     single    pusher   Don      4.2093e-06          0
# Jets    20s    JH     single    pusher   Phil     7.57675e-05         0
# Jets    20s    JH     single    pusher   Neal     7.57675e-05         0
# Jets    20s    JH     single    pusher   Greg     0.0122743           0
# Jets    20s    JH     single    pusher   Gene     0.220938            0
# Jets    20s    JH     single    pusher   Art      0.220938            0
# Jets    20s    JH     divorced  bookie   Phil     8.06172e-06         0
# Jets    20s    JH     divorced  bookie   Neal     0.000145111         0
# Jets    20s    JH     divorced  bookie   Greg     0.001306            0
# Jets    20s    JH     divorced  bookie   Gene     0.001306            0
# Jets    20s    JH     divorced  bookie   Art      0.001306            0
# Jets    20s    JH     divorced  bookie   Sam      0.023508            0
# Jets    20s    JH     divorced  bookie   Al       0.001306            0
# Jets    20s    JH     divorced  bookie   Doug     0.001306            0
# Jets    20s    JH     divorced  bookie   George   0.423144            0
# Jets    20s    JH     divorced  bookie   Karl     0.000145111         0
# Jets    20s    JH     divorced  burglar  Pete     8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Ned      5.00087e-07         0
# Jets    20s    JH     divorced  burglar  Jim      0.472474            1
# Jets    20s    JH     divorced  burglar  Ralph    8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Nick     5.00087e-07         0
# Jets    20s    JH     divorced  burglar  Clyde    8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Rick     0.000162028         0
# Jets    20s    JH     divorced  burglar  John     0.0262486           0
# Jets    20s    JH     divorced  burglar  Lance    0.0262486           0
# Jets    20s    JH     divorced  burglar  Ken      0.000162028         0
# Jets    20s    JH     divorced  burglar  Mike     8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Fred     8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Dave     9.00156e-06         0
# Jets    20s    JH     divorced  burglar  Ike      9.00156e-06         0
# Jets    20s    JH     divorced  burglar  Earl     9.00156e-06         0
# Jets    20s    JH     divorced  burglar  Ol       5.00087e-07         0
# Jets    20s    JH     divorced  burglar  Don      9.00156e-06         0
# Jets    20s    JH     divorced  burglar  Phil     5.00087e-07         0
# Jets    20s    JH     divorced  burglar  Neal     5.00087e-07         0
# Jets    20s    JH     divorced  burglar  Greg     8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Gene     8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Art      8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Sam      8.10141e-05         0
# Jets    20s    JH     divorced  burglar  Al       0.00145825          0
# Jets    20s    JH     divorced  burglar  Doug     4.50078e-06         0
# Jets    20s    JH     divorced  burglar  George   0.472474            1
# Jets    20s    JH     divorced  burglar  Karl     5.00087e-07         0
# Jets    20s    JH     divorced  pusher   Pete     0.00127918          0
# Jets    20s    JH     divorced  pusher   Ned      7.89615e-06         0
# Jets    20s    JH     divorced  pusher   Jim      0.414453            0
# Jets    20s    JH     divorced  pusher   Ralph    0.0230252           0
# Jets    20s    JH     divorced  pusher   Nick     0.000142131         0
# Jets    20s    JH     divorced  pusher   Clyde    0.00127918          0
# Jets    20s    JH     divorced  pusher   Rick     0.000142131         0
# Jets    20s    JH     divorced  pusher   John     0.0230252           0
# Jets    20s    JH     divorced  pusher   Lance    0.0230252           0
# Jets    20s    JH     divorced  pusher   Ken      0.000142131         0
# Jets    20s    JH     divorced  pusher   Mike     0.00127918          0
# Jets    20s    COL    single    burglar  Lance    0.0224467           0
# Jets    20s    COL    single    burglar  Ken      0.0448933           0
# Jets    20s    COL    single    burglar  Mike     0.00124704          0
# Jets    20s    COL    single    burglar  Fred     0.0224467           0
# Jets    20s    COL    single    burglar  Dave     7.69776e-06         0
# Jets    20s    COL    single    burglar  Ike      0.00013856          0
# Jets    20s    COL    single    burglar  Earl     0.00013856          0
# Jets    20s    COL    single    burglar  Ol       0.00013856          0
# Jets    20s    COL    single    burglar  Don      0.00249407          0
# Jets    20s    COL    single    burglar  Phil     0.00013856          0
# Jets    20s    COL    single    burglar  Neal     0.00013856          0
# Jets    20s    COL    single    burglar  Greg     0.00124704          0
# Jets    20s    COL    single    burglar  Gene     0.40404             0
# Jets    20s    COL    single    burglar  Art      0.00124704          0
# Jets    20s    COL    single    burglar  Sam      0.40404             0
# Jets    20s    COL    single    burglar  Al       0.00124704          0
# Jets    20s    COL    single    burglar  Doug     0.00124704          0
# Jets    20s    COL    single    burglar  George   0.0224467           0
# Jets    20s    COL    single    burglar  Karl     7.69776e-06         0
# Jets    20s    COL    single    pusher   Pete     0.00274071          0
# Jets    20s    COL    single    pusher   Ned      1.6918e-05          0
# Jets    20s    COL    single    pusher   Jim      0.000152262         0
# Jets    20s    COL    single    pusher   Ralph    0.00274071          0
# Jets    20s    COL    single    pusher   Nick     0.000304524         0
# Jets    20s    COL    single    pusher   Clyde    0.000152262         0
# Jets    20s    COL    single    pusher   Rick     9.39888e-07         0
# Jets    20s    COL    single    pusher   John     0.000152262         0
# Jets    20s    COL    single    pusher   Lance    0.000152262         0
# Jets    20s    COL    single    pusher   Ken      0.000304524         0
# Jets    20s    COL    single    pusher   Mike     0.000152262         0
# Jets    20s    COL    single    pusher   Fred     0.0493329           0
# Jets    20s    COL    single    pusher   Dave     1.6918e-05          0
# Jets    20s    COL    single    pusher   Ike      1.6918e-05          0
# Jets    20s    COL    single    pusher   Earl     9.39888e-07         0
# Jets    20s    COL    single    pusher   Ol       0.000304524         0
# Jets    20s    COL    single    pusher   Don      1.6918e-05          0
# Jets    20s    COL    single    pusher   Phil     0.000304524         0
# Jets    20s    COL    single    pusher   Neal     1.6918e-05          0
# Jets    20s    COL    single    pusher   Greg     0.00274071          0
# Jets    20s    COL    single    pusher   Gene     0.887992            1
# Jets    20s    COL    single    pusher   Art      0.00274071          0
# Jets    20s    COL    single    pusher   Sam      0.0493329           0
# Jets    20s    COL    single    pusher   Al       8.459e-06           0
# Jets    20s    COL    single    pusher   Doug     0.000152262         0
# Jets    20s    COL    single    pusher   George   0.000152262         0
# Jets    20s    COL    single    pusher   Karl     9.39888e-07         0
# Jets    20s    COL    married   bookie   Pete     0.0386619           0
# Jets    20s    COL    married   bookie   Ned      0.0773239           0
# Jets    20s    COL    married   bookie   Jim      0.00214789          0
# Jets    20s    COL    married   bookie   Ralph    0.000119327         0
# Jets    20s    COL    married   bookie   Nick     1.32586e-05         0
# Jets    20s    COL    married   bookie   Clyde    0.00214789          0
# Sharks  40s    COL    divorced  pusher   Ol       0.277002            0
# Sharks  40s    COL    divorced  pusher   Don      0.015389            0
# Sharks  40s    COL    divorced  pusher   Phil     0.277002            0
# Sharks  40s    COL    divorced  pusher   Neal     0.000854944         0
# Sharks  40s    COL    divorced  pusher   Greg     0.00170989          0
# Sharks  40s    COL    divorced  pusher   Gene     0.030778            0
# Sharks  40s    COL    divorced  pusher   Art      0.030778            0
# Sharks  40s    COL    divorced  pusher   Sam      0.00170989          0
# Sharks  40s    COL    divorced  pusher   Al       9.49938e-05         0
# Sharks  40s    COL    divorced  pusher   Doug     9.49938e-05         0
# Sharks  40s    COL    divorced  pusher   George   0.00170989          0
# Sharks  40s    COL    divorced  pusher   Karl     0.015389            0

# %%
cond = ConditionalProbabilityTable(CPT, dist[:-1])
name = State(cond, name="name")
gang = State(distributions["gang"], name="gang")
age = State(distributions["age"], name="age")
edu = State(distributions["edu"], name="edu")
mar = State(distributions["mar"], name="mar")
occ = State(distributions["occ"], name="occ")

model = BayesianNetwork("Jets and Sharks")
model.add_states(gang, age, edu, mar, occ, name)

model.add_edge(gang, name)
model.add_edge(age, name)
model.add_edge(edu, name)
model.add_edge(mar, name)
model.add_edge(occ, name)
model.bake()
# print(model.predict_proba({}))

# %%
# print(prob({'gang': 'Jets', 'occ': 'pusher'},{'mar': 'single'}))
# print(model.predict_proba({'occ': 'bookie' ,'mar': 'single'}))
# print(prob({'name': 'Lance', 'occ': 'pusher'},{'mar': 'single'}))
# print(model.predict_proba({'name': 'Lance', 'occ': 'pusher'}))
# print(model.predict_proba({'gang': 'Sharks', 'age': '20s'}))
print(model.predict_proba({'gang': 'Jets'}))
# print(model.predict_proba({'name': 'John'}))
# print(prob({},{'gang': 'Jets'}))
# print(prob({},{'name': 'John'x}))
# Out:
# ['Jets'
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "20s" :0.5081771601038815,
#             "30s" :0.42612479820313043,
#             "40s" :0.06569804169298818
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "HS" :0.4084368639011721,
#             "JH" :0.47504737839545147,
#             "COL" :0.10949673615498019,
#             "JS" :0.00701902154839625
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "single" :0.7199410402189932,
#             "married" :0.22952200463255432,
#             "divorced" :0.05053695514845243
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "pusher" :0.3719379518495122,
#             "burglar" :0.20284972274864901,
#             "bookie" :0.42521232540183884
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "Pete" :0.10037200814206472,
#             "Ned" :0.0,
#             "Jim" :0.025268477574226275,
#             "Ralph" :0.10675931775110506,
#             "Nick" :0.0,
#             "Clyde" :0.03284902084649404,
#             "Rick" :0.0,
#             "John" :0.0631711939355653,
#             "Lance" :0.007019021548396378,
#             "Ken" :0.0,
#             "Mike" :0.10675931775110506,
#             "Fred" :0.10037200814206472,
#             "Dave" :0.0,
#             "Ike" :0.0,
#             "Earl" :0.0,
#             "Ol" :0.0,
#             "Don" :0.0,
#             "Phil" :0.0,
#             "Neal" :0.0,
#             "Greg" :0.0772092370323575,
#             "Gene" :0.05474836807748991,
#             "Art" :0.03284902084649404,
#             "Sam" :0.05474836807748991,
#             "Al" :0.0821225521162347,
#             "Doug" :0.13048361058468383,
#             "George" :0.025268477574226275,
#             "Karl" :0.0
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }]

# %%
print(model.predict_proba({'occ': 'pusher'}))
# Out:
# [{
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "Jets" :0.6240137544454651,
#             "Sharks" :0.37598624555453497
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "20s" :0.38978779528486274,
#             "30s" :0.5551002143244071,
#             "40s" :0.055111990390730045
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "HS" :0.5269554158129017,
#             "JH" :0.23422595916060174,
#             "COL" :0.23881862502649648,
#             "JS" :0.0
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "single" :0.6696106832473678,
#             "married" :0.27650203725947375,
#             "divorced" :0.05388727949315829
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }
#  'pusher'
#  {
#     "frozen" :false,
#     "dtype" :"str",
#     "class" :"Distribution",
#     "parameters" :[
#         {
#             "Pete" :0.0,
#             "Ned" :0.0,
#             "Jim" :0.0,
#             "Ralph" :0.1791139687698713,
#             "Nick" :0.17513365835276315,
#             "Clyde" :0.0,
#             "Rick" :0.0,
#             "John" :0.0,
#             "Lance" :0.0,
#             "Ken" :0.0,
#             "Mike" :0.0,
#             "Fred" :0.16839774841611818,
#             "Dave" :0.05388727949315812,
#             "Ike" :0.0,
#             "Earl" :0.0,
#             "Ol" :0.07348265385430641,
#             "Don" :0.0,
#             "Phil" :0.07348265385430641,
#             "Neal" :0.0,
#             "Greg" :0.12953672955086024,
#             "Gene" :0.09185331731788288,
#             "Art" :0.0551119903907298,
#             "Sam" :0.0,
#             "Al" :0.0,
#             "Doug" :0.0,
#             "George" :0.0,
#             "Karl" :0.0
#         }
#     ],
#     "name" :"DiscreteDistribution"
# }]
